# %% [markdown]
# <a href="https://colab.research.google.com/github/mguerrahahn/my-dataproject/blob/main/Penguin_Fun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Packages

# %%
library(tidyverse)

# %% [markdown]
# # Penguin Plot

# %%
penguins <- read_csv("/content/penguins.csv")
penguins |>
  ggplot(aes(x = bill_length_mm, y = bill_depth_mm, color = species)) +
  geom_point()
